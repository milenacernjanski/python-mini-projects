# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
# draw square in Python Turtle

import ColabTurtle.Turtle as t
initializeTurtle()

s = 50

# drawing first side
t.forward(s) # Forward turtle by s units
t.left(90) # Turn turtle by 90 degree

# drawing second side
t.forward(s) # Forward turtle by s units
t.left(90) # Turn turtle by 90 degree

# drawing third side
t.forward(s) # Forward turtle by s units
t.left(90) # Turn turtle by 90 degree

# drawing fourth side
t.forward(s) # Forward turtle by s units
t.left(90) # Turn turtle by 90 degree
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
# !pip3 install ColabTurtle                    # installs ColabTurtle module
from ColabTurtle.Turtle import *             # the astrisk means import everything

import ColabTurtle.Turtle as maggie          # create an alias called "maggie" for a turtle object
initializeTurtle()                           # initializing the turtle environment


def draw_square(color, forward, left,):      # create a funnction

# draw first side
  maggie.color('cornflowerblue')             # change color first to start with some color
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw second side
  maggie.color('hotpink')                    # change color
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw third side
  maggie.color('mediumpurple')               # change color again to be more fun
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw fourth side
  maggie.color('lawngreen')                  # change color again to be more fun
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# call the function so it actually works
draw_square('color', 50, 90)
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:cornflowerblue;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:hotpink;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:mediumpurple;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:lawngreen;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %% [markdown]
# # EXTRA CREDIT

# %%
# !pip3 install ColabTurtle                    # installs ColabTurtle module
from ColabTurtle.Turtle import *             # the astrisk means import everything

import ColabTurtle.Turtle as maggie          # create an alias called "maggie" for a turtle object
initializeTurtle()                           # initializing the turtle environment


def draw_square(color, forward, left,):      # create a funnction

# draw first side
  maggie.color('cornflowerblue')             # change color first to start with some color
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw second side
  maggie.color('hotpink')                    # change color
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw third side
  maggie.color('mediumpurple')               # change color again to be more fun
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# draw fourth side
  maggie.color('lawngreen')                  # change color again to be more fun
  maggie.forward(forward)                    # forward turtle
  maggie.left(left)                          # turn turtle to the left

# call the function so it actually works
draw_square('color', 50, 90)

while True:
    print("Choose an option:")
    print("1. Draw a square")
    print("2. Draw a triangle")
    print("3. Draw a circle")
    print("3. Clear the screen")
    print("4. Quit")

    user_input = input("Enter the number of your choice (1-6): ")

    if choice == '1':
        color = (input("Enter color of  turtle maggie: "))
        forward = (input("Enter number for forward: "))
        left = (input("Enter number for left: "))
        draw_square(color, forward, left)
    elif choice == '2':
        radius = int(input("Enter the radius of the circle: "))
        draw_circle(radius)
    elif choice == '3':
        size = int(input("Enter the size of the triangle: "))
        draw_triangle(size)
    elif choice == '4':
        sides = int(input("Enter the number of sides for the custom shape: "))
        size = int(input("Enter the size of the sides: "))
        draw_custom_shape(sides, size)
    elif choice == '5':
        clear_screen()
    elif choice == '6':
        print("Exiting program.")
        break
    else:
        print("Invalid choice. Please select a valid option.")

# Close the turtle graphics window when done
maggie.done()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="240.0" x2="400.0" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="240.0" x2="391.34" y2="235.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,391.34,235.0) translate(373.34, 217.0)">
# ...

# %%
# !pip3 install ColabTurtle                    # installs ColabTurtle module
from ColabTurtle.Turtle import *             # the astrisk means import everything

import ColabTurtle.Turtle as t         # create an alias called "maggie" for a turtle object
initializeTurtle()

# Install ColabTurtle module (only required for Google Colab)
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

initializeTurtle()

# Define a function to draw a square
def draw_square(side_length):
    for _ in range(4):
        forward(side_length)
        left(90)

while True:
    print("Select a shape to draw:")
    print("1. Square")
    print("2. Quit")

    choice = input("Enter your choice (1/2): ")

    if choice == '1':
        side_length = float(input("Enter the square side length: "))
        draw_square(side_length)
    elif choice == '2':
        print("Goodbye!")
        break
    else:
        print("Invalid choice. Please enter 1 or 2.")
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
def add(a, b):
    return a + b

result = add(3, 4)
print(result)  # Output: 7
# Out:
# 7

# %%
def multiply(a, b):
    result = a * b
    return result

def main():
    x = 5
    y = 3
    z = multiply(x, y)
    print(f"The result of {x} * {y} is {z}")

if __name__ == "__main__":
    main()
# Out:
# The result of 5 * 3 is 15
