# %%
def start_quiz():
    print("🎯 Welcome to the Data Analyst Career Path Quiz!")
    print("Let's figure out what kind of data analysis career might suit you best.")
    print("-" * 50)

    # First question
    answer1 = input("Do you enjoy working more with people or with code? (people/code): ")

    # Just storing answer for now
    print(f"You answered: {answer1}")

    # Placeholder for next steps
    print("Great! More questions coming soon...")

# Run the quiz
start_quiz()
# Out:
# 🎯 Welcome to the Data Analyst Career Path Quiz!
# Let's figure out what kind of data analysis career might suit you best.
# --------------------------------------------------
# Do you enjoy working more with people or with code? (people/code): people
# You answered: people
# Great! More questions coming soon...

# %%
def start_quiz():
    print("🎯 Welcome to the Data Analyst Career Path Quiz!")
    print("Let's figure out what kind of data analysis career might suit you best.")
    print("-" * 50)

    # Personalized first question
    answer1 = input("Which of these areas excites you the most?\n"
                    "A) Understanding how food impacts performance (nutrition)\n"
                    "B) Helping a business make smart decisions\n"
                    "C) Creating predictive models with code\n"
                    "D) Turning data into visuals to tell stories\n"
                    "Enter A, B, C or D: ").strip().upper()

    print(f"You chose option: {answer1}")

    print("Great! More questions coming soon...")

# Run the quiz
start_quiz()
# Out:
# 🎯 Welcome to the Data Analyst Career Path Quiz!
# Let's figure out what kind of data analysis career might suit you best.
# --------------------------------------------------
# Which of these areas excites you the most?
# A) Understanding how food impacts performance (nutrition)
# B) Helping a business make smart decisions
# C) Creating predictive models with code
# D) Turning data into visuals to tell stories
# Enter A, B, C or D: A
# You chose option: A
# Great! More questions coming soon...
